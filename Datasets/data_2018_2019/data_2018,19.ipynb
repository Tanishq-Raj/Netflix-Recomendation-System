# %% [markdown]
# ### 2018 Data

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018" # fetching all the 2018 movies from wikipedia
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df4.sample(2)
# Out:
#             Opening  Opening.1                           Title  \
# 45  N O V E M B E R         30  The Possession of Hannah Grace
# 10    O C T O B E R         19                       Halloween
#
#                                    Production company  \
# 45                                        Screen Gems
# 10  Universal Pictures / Miramax / Blumhouse Produ...
#
#                                         Cast and crew   Ref.
# 45  Diederik van Rooijen (director); Brian Sieve (...  [225]
# 10  David Gordon Green (director/screenplay); Jeff...  [192]

# %%
df = pd.concat([df1,df2,df3,df4],ignore_index=True) #concat all the dataframes in a single for preprocessing
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 243  D E C E M B E R         21               Second Act
# 244  D E C E M B E R         25          Holmes & Watson
# 245  D E C E M B E R         25                     Vice
# 246  D E C E M B E R         25      On the Basis of Sex
# 247  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 243                                  STX Entertainment
# 244  Columbia Pictures / Gary Sanchez Productions /...
# 245          Annapurna Pictures / Plan B Entertainment
# 246                                     Focus Features
# 247                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 243  Peter Segal (director); Justin Zackham, Elaine...  [237]
# 244  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 245  Adam McKay (director/screenplay); Christian Ba...  [117]
# 246  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 247  Karyn Kusama (director); Phil Hay, Matt Manfre...  [238]
#
# [248 rows x 6 columns]

# %% [markdown]
# #### As it is observed in the above table, we do not have the genre column so we will get the genre data from IMDb. You will need to create an API key in order to access the API key.
#
# ### pip install tmdbv3api

# %%
#get your API Key here: https://www.themoviedb.org/settings/api
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()

api = 'cf1e5b9d8cf31e19913dd6bc256abb2a'
tmdb.api_key=api # insert your api key here

# %%
from tmdbv3api import Movie

tmdb_movie = Movie()

def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}') #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.nan # we will return the results but if we don't find anything we will consider it as a missing value

# %%
df['genres']= df['Title'].map(lambda x : get_genre(x))

df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 243  D E C E M B E R         21               Second Act
# 244  D E C E M B E R         25          Holmes & Watson
# 245  D E C E M B E R         25                     Vice
# 246  D E C E M B E R         25      On the Basis of Sex
# 247  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 243                                  STX Entertainment
# 244  Columbia Pictures / Gary Sanchez Productions /...
# 245          Annapurna Pictures / Plan B Entertainment
# 246                                     Focus Features
# 247                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 243  Peter Segal (director); Justin Zackham, Elaine...  [237]
# 244  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 245  Adam McKay (director/screenplay); Christian Ba...  [117]
# 246  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 247  Karyn Kusama (director); Phil Hay, Matt Manfre...  [238]
#
#                                         genres
# 0                              Horror Thriller
# 1                                Drama Mystery
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                        Action Crime Thriller
# ..                                         ...
# 243                             Romance Comedy
# 244                       Comedy Mystery Crime
# 245  Thriller Science Fiction Action Adventure
# 246                              Drama History
# 247                Thriller Crime Drama Action
#
# [248 rows x 7 columns]

# %%
import re
import pandas as pd

def extract_info(text):
    # Initialize the director to None
    director_name = None
    # Initialize the actors to None
    actor_1, actor_2, actor_3 = None, None, None
    
    # Check if the text contains a director's name and role(s)
    director_match = re.search(r'([a-zA-Z\s]+) \(([^)]+)\)', text)  # Extract name and roles inside parentheses
    if director_match:
        name = director_match.group(1).strip()  # Extract the name (e.g., Michael Moore)
        roles = director_match.group(2).strip()  # Extract the roles (e.g., director/screenplay/narrator)
        
        # If 'director' is in the roles, assign only the name to the director column
        if 'director' in roles:
            director_name = name  # Only assign the name to the director column if 'director' is present in the roles
            
            # Remove the director's name from the actors list to avoid duplication
            text = text.replace(name + " (" + roles + ")", "")  # Remove the entire director's entry

    # Extract actors from the cast and crew field (after the last semicolon)
    actors = re.split(r';', text)[-1].strip().split(', ')  # Split by semicolon and take actors from the last part
    
    # Remove the director from the actors list (if it was listed there)
    actors = [actor for actor in actors if actor != director_name]
    
    # Assign actors if they exist
    actor_1 = actors[0] if len(actors) > 0 else None
    actor_2 = actors[1] if len(actors) > 1 else None
    actor_3 = actors[2] if len(actors) > 2 else None

    # Return the extracted information in a pandas Series
    return pd.Series([director_name, actor_1, actor_2, actor_3])

# %%
df[['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name']] = df['Cast and crew'].apply(extract_info)

# %%
df=df.rename(columns={'Title':'movie_title'})
df.sample(2)
# Out:
#              Opening  Opening.1  movie_title  \
# 234  D E C E M B E R          7  Ben Is Back
# 86             M A Y         11     Terminal
#
#                                     Production company  \
# 234  LD Entertainment / Lionsgate / Roadside Attrac...
# 86                                          RLJE Films
#
#                                          Cast and crew   Ref.  \
# 234  Peter Hedges (director/screenplay); Julia Robe...  [228]
# 86   Vaughn Stein (director/screenplay); Margot Rob...   [83]
#
#                    genres director_name   actor_1_name  actor_2_name  \
# 234                 Drama  Peter Hedges  Julia Roberts  Lucas Hedges
# 86   Crime Drama Thriller  Vaughn Stein  Margot Robbie    Simon Pegg
#
#           actor_3_name
# 234  Courtney B. Vance
# 86     Dexter Fletcher

# %%
new_df18 = df[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df18.sample(2)
# Out:
#             director_name   actor_1_name            actor_2_name  \
# 1    Christopher Radcliff  Alex Pettyfer  James Freedson-Jackson
# 124    Genndy Tartakovsky   Adam Sandler            Andy Samberg
#
#       actor_3_name                           genres  \
# 1    Emily Althaus                    Drama Mystery
# 124   Selena Gomez  Animation Comedy Family Fantasy
#
#                                movie_title
# 1                         The Strange Ones
# 124  Hotel Transylvania 3: Summer Vacation

# %%
new_df18.isna().sum()
# Out:
# director_name     3
# actor_1_name      0
# actor_2_name      4
# actor_3_name     15
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df18.fillna('unknown',inplace=True)
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_24768\1743747590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df18.fillna('unknown',inplace=True)

# %%
new_df18.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df18['movie_title']= new_df18['movie_title'].str.lower()
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_24768\1947154767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df18['movie_title']= new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18.head()
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_24768\1846478324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
#           director_name      actor_1_name            actor_2_name  \
# 0          Adam Robitel         Lin Shaye           Angus Sampson
# 1  Christopher Radcliff     Alex Pettyfer  James Freedson-Jackson
# 2                 Serra       Liam Neeson            Vera Farmiga
# 3          Babak Najafi  Taraji P. Henson    Jahi Di'Allo Winston
# 4         Brett Donowho      Bruce Willis             Cole Hauser
#
#      actor_3_name                   genres              movie_title  \
# 0  Leigh Whannell          Horror Thriller  insidious: the last key
# 1   Emily Althaus            Drama Mystery         the strange ones
# 2  Patrick Wilson  Action Thriller Mystery             the commuter
# 3     Billy Brown    Thriller Action Crime               proud mary
# 4   Shawn Ashmore    Action Crime Thriller         acts of violence
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2  Liam Neeson Vera Farmiga Patrick Wilson Serra ...
# 3  Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4  Bruce Willis Cole Hauser Shawn Ashmore Brett D...

# %% [markdown]
# ### Data 2019

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019" # fetching all the 2019 movies from wikipedia
df5 = pd.read_html(link, header=0)[2]
df6 = pd.read_html(link, header=0)[3]
df7 = pd.read_html(link, header=0)[4]
df8 = pd.read_html(link, header=0)[5]

# %%
df9 = pd.concat([df5,df6,df7,df8],ignore_index=True) #concat all the dataframes in a single for preprocessing
df9
# Out:
#              Opening Opening.1              Title  \
# 0      J A N U A R Y         4        Escape Room
# 1      J A N U A R Y         4         Rust Creek
# 2      J A N U A R Y         4   American Hangman
# 3      J A N U A R Y        11   A Dog's Way Home
# 4      J A N U A R Y        11         The Upside
# ..               ...       ...                ...
# 245  D E C E M B E R        25  Spies in Disguise
# 246  D E C E M B E R        25       Little Women
# 247  D E C E M B E R        25               1917
# 248  D E C E M B E R        25         Just Mercy
# 249  D E C E M B E R        27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 245  20th Century Fox Animation / Blue Sky Studios ...
# 246            Columbia Pictures / Regency Enterprises
# 247           Universal Pictures / DreamWorks Pictures
# 248          Warner Bros. Pictures / Participant Media
# 249                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 245  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 246  Greta Gerwig (director/screenplay); Saoirse Ro...  [226]
# 247  Sam Mendes (director/screenplay); Krysty Wilso...  [227]
# 248  Destin Daniel Cretton (director/screenplay), A...  [228]
# 249  Chinonye Chukwu (director/screenplay); Alfre W...  [229]
#
# [250 rows x 6 columns]

# %%
df9['genres']= df9['Title'].map(lambda x : get_genre(x))

df9
# Out:
#              Opening Opening.1              Title  \
# 0      J A N U A R Y         4        Escape Room
# 1      J A N U A R Y         4         Rust Creek
# 2      J A N U A R Y         4   American Hangman
# 3      J A N U A R Y        11   A Dog's Way Home
# 4      J A N U A R Y        11         The Upside
# ..               ...       ...                ...
# 245  D E C E M B E R        25  Spies in Disguise
# 246  D E C E M B E R        25       Little Women
# 247  D E C E M B E R        25               1917
# 248  D E C E M B E R        25         Just Mercy
# 249  D E C E M B E R        27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 245  20th Century Fox Animation / Blue Sky Studios ...
# 246            Columbia Pictures / Regency Enterprises
# 247           Universal Pictures / DreamWorks Pictures
# 248          Warner Bros. Pictures / Participant Media
# 249                                               Neon
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 245  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 246  Greta Gerwig (director/screenplay); Saoirse Ro...  [226]
# 247  Sam Mendes (director/screenplay); Krysty Wilso...  [227]
# 248  Destin Daniel Cretton (director/screenplay), A...  [228]
# 249  Chinonye Chukwu (director/screenplay); Alfre W...  [229]
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 245  Animation Action Adventure Comedy Family
# 246                     Drama Romance History
# 247                War History Thriller Drama
# 248                       Drama Crime History
# 249                                     Drama
#
# [250 rows x 7 columns]

# %%
df9[['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name']] = df9['Cast and crew'].apply(extract_info)
df9.head(7)
# Out:
#          Opening Opening.1             Title  \
# 0  J A N U A R Y         4       Escape Room
# 1  J A N U A R Y         4        Rust Creek
# 2  J A N U A R Y         4  American Hangman
# 3  J A N U A R Y        11  A Dog's Way Home
# 4  J A N U A R Y        11        The Upside
# 5  J A N U A R Y        11          Replicas
# 6  J A N U A R Y        15    After Darkness
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
# 4                  STX Entertainment
# 5              Entertainment Studios
# 6     Grindstone Entertainment Group
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]
# 5  Jeffrey Nachmanoff (director); Chad St. John (...  [7]
# 6  Batán Silva (director); Fernando Diez Barroso ...  [8]
#
#                                   genres         director_name  \
# 0                Horror Thriller Mystery          Adam Robitel
# 1            Thriller Drama Action Crime           Jen McGowan
# 2                               Thriller     Wilson Coneybeare
# 3                 Drama Adventure Family  Charles Martin Smith
# 4                           Comedy Drama           Neil Burger
# 5         Science Fiction Thriller Drama    Jeffrey Nachmanoff
# 6  Drama Family Thriller Science Fiction               n Silva
#
#           actor_1_name        actor_2_name      actor_3_name
# 0       Taylor Russell        Logan Miller  Deborah Ann Woll
# 1    Hermione Corfield         Jay Paulson      Sean O'Bryan
# 2    Donald Sutherland  Vincent Kartheiser     Oliver Dennis
# 3  Bryce Dallas Howard  Edward James Olmos   Alexandra Shipp
# 4       Bryan Cranston          Kevin Hart     Nicole Kidman
# 5         Keanu Reeves                None              None
# 6         Natalia Dyer       Kyra Sedgwick          Tim Daly

# %%
df9=df9.rename(columns={'Title':'movie_title'})
df9.head(4)
# Out:
#          Opening Opening.1       movie_title  \
# 0  J A N U A R Y         4       Escape Room
# 1  J A N U A R Y         4        Rust Creek
# 2  J A N U A R Y         4  American Hangman
# 3  J A N U A R Y        11  A Dog's Way Home
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
#
#                         genres         director_name         actor_1_name  \
# 0      Horror Thriller Mystery          Adam Robitel       Taylor Russell
# 1  Thriller Drama Action Crime           Jen McGowan    Hermione Corfield
# 2                     Thriller     Wilson Coneybeare    Donald Sutherland
# 3       Drama Adventure Family  Charles Martin Smith  Bryce Dallas Howard
#
#          actor_2_name      actor_3_name
# 0        Logan Miller  Deborah Ann Woll
# 1         Jay Paulson      Sean O'Bryan
# 2  Vincent Kartheiser     Oliver Dennis
# 3  Edward James Olmos   Alexandra Shipp

# %%
new_df19 = df9[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df19.sample(2)
# Out:
#         director_name    actor_1_name   actor_2_name       actor_3_name  \
# 58           Leonetti  Kiernan Shipka  Stanley Tucci       Miranda Otto
# 158  Matthew Thompson  Josh Pinkowski    Izzy Pollak  Blake Kevin Dwyer
#
#                             genres      movie_title
# 58   Horror Drama Thriller Fantasy      The Silence
# 158                         Family  Debunkers, Inc.

# %%
new_df19.isna().sum()
# Out:
# director_name     2
# actor_1_name      0
# actor_2_name      3
# actor_3_name     20
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df19.fillna('unknown',inplace=True)
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_24768\2497761090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df19.fillna('unknown',inplace=True)

# %%
new_df19.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df19['movie_title']= new_df19['movie_title'].str.lower()
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_24768\1129895483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df19['movie_title']= new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19.head()
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_24768\602706098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2  Donald Sutherland Vincent Kartheiser Oliver De...
# 3  Bryce Dallas Howard Edward James Olmos Alexand...
# 4  Bryan Cranston Kevin Hart Nicole Kidman Neil B...

# %%
my_df = pd.concat([new_df18,new_df19],ignore_index=True)

my_df
# Out:
#              director_name       actor_1_name            actor_2_name  \
# 0             Adam Robitel          Lin Shaye           Angus Sampson
# 1     Christopher Radcliff      Alex Pettyfer  James Freedson-Jackson
# 2                    Serra        Liam Neeson            Vera Farmiga
# 3             Babak Najafi   Taraji P. Henson    Jahi Di'Allo Winston
# 4            Brett Donowho       Bruce Willis             Cole Hauser
# ..                     ...                ...                     ...
# 493             Troy Quane         Will Smith             Tom Holland
# 494           Greta Gerwig      Saoirse Ronan             Emma Watson
# 495             Sam Mendes      George MacKay    Dean-Charles Chapman
# 496  Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 497        Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                           Horror Thriller
# 1     Emily Althaus                             Drama Mystery
# 2    Patrick Wilson                   Action Thriller Mystery
# 3       Billy Brown                     Thriller Action Crime
# 4     Shawn Ashmore                     Action Crime Thriller
# ..              ...                                       ...
# 493   Rashida Jones  Animation Action Adventure Comedy Family
# 494   Florence Pugh                     Drama Romance History
# 495     Mark Strong                War History Thriller Drama
# 496     Brie Larson                       Drama Crime History
# 497     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 493        spies in disguise
# 494             little women
# 495                     1917
# 496               just mercy
# 497                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Serra ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 493  Will Smith Tom Holland Rashida Jones Troy Quan...
# 494  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 495  George MacKay Dean-Charles Chapman Mark Strong...
# 496  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 497  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [498 rows x 7 columns]

# %%
old = pd.read_csv(r'D:\Data Science Pojects\Netflix Recommendation System\data_2017\new_data.csv')

old.sample(2)
# Out:
#          director_name  actor_1_name    actor_2_name   actor_3_name  \
# 1560  Peter Lepeniotis   Liam Neeson  Brendan Fraser    Sarah Gadon
# 1397       Kevin Smith  Stephen Root      Mike Starr  George Carlin
#
#       movie_title                             genres  \
# 1560  the nut job  Adventure Animation Comedy Family
# 1397  jersey girl               Comedy Drama Romance
#
#                                                    comb
# 1560  Liam Neeson Brendan Fraser Sarah Gadon Peter L...
# 1397  Stephen Root Mike Starr George Carlin Kevin Sm...

# %%
final = pd.concat([old,my_df],ignore_index=True)
final
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5871             Troy Quane         Will Smith           Tom Holland
# 5872           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5873             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5874  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5875        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                        movie_title  \
# 0                Wes Studi                                             avatar
# 1           Jack Davenport           pirates of the caribbean: at world's end
# 2         Stephanie Sigman                                            spectre
# 3     Joseph Gordon-Levitt                              the dark knight rises
# 4                  unknown  star wars: episode vii - the force awakens    ...
# ...                    ...                                                ...
# 5871         Rashida Jones                                  spies in disguise
# 5872         Florence Pugh                                       little women
# 5873           Mark Strong                                               1917
# 5874           Brie Larson                                         just mercy
# 5875           Aldis Hodge                                           clemency
#
#                                         genres  \
# 0              Action Adventure Fantasy Sci-Fi
# 1                     Action Adventure Fantasy
# 2                    Action Adventure Thriller
# 3                              Action Thriller
# 4                                  Documentary
# ...                                        ...
# 5871  Animation Action Adventure Comedy Family
# 5872                     Drama Romance History
# 5873                War History Thriller Drama
# 5874                       Drama Crime History
# 5875                                     Drama
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5871  Will Smith Tom Holland Rashida Jones Troy Quan...
# 5872  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5873  George MacKay Dean-Charles Chapman Mark Strong...
# 5874  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5875  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5876 rows x 7 columns]

# %%
final.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# movie_title      0
# genres           0
# comb             0
# dtype: int64

# %%
final.drop_duplicates(keep='last',inplace=True)

final
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5871             Troy Quane         Will Smith           Tom Holland
# 5872           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5873             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5874  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5875        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                        movie_title  \
# 0                Wes Studi                                             avatar
# 1           Jack Davenport           pirates of the caribbean: at world's end
# 2         Stephanie Sigman                                            spectre
# 3     Joseph Gordon-Levitt                              the dark knight rises
# 4                  unknown  star wars: episode vii - the force awakens    ...
# ...                    ...                                                ...
# 5871         Rashida Jones                                  spies in disguise
# 5872         Florence Pugh                                       little women
# 5873           Mark Strong                                               1917
# 5874           Brie Larson                                         just mercy
# 5875           Aldis Hodge                                           clemency
#
#                                         genres  \
# 0              Action Adventure Fantasy Sci-Fi
# 1                     Action Adventure Fantasy
# 2                    Action Adventure Thriller
# 3                              Action Thriller
# 4                                  Documentary
# ...                                        ...
# 5871  Animation Action Adventure Comedy Family
# 5872                     Drama Romance History
# 5873                War History Thriller Drama
# 5874                       Drama Crime History
# 5875                                     Drama
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5871  Will Smith Tom Holland Rashida Jones Troy Quan...
# 5872  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5873  George MacKay Dean-Charles Chapman Mark Strong...
# 5874  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5875  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5876 rows x 7 columns]

# %%
final.to_csv('final_data.csv',index=False)
